# %%
import pandas as pd
import matplotlib.pyplot as plt


# Read the CSV file into a DataFrame with semicolon delimiter
df = pd.read_csv('tables/country_talent_gs_mostcrowdet_toless.csv', delimiter=';')

# Display the DataFrame
print(df)
# Out:
#                      country  talent  government_strategy  population
# 0                      China   16.51                94.87  1425887337
# 1                      India   45.27                58.83  1417173173
# 2   United States of America  100.00                77.39   338289857
# 3                  Indonesia    5.51                59.99   275501339
# 4                   Pakistan    8.00                13.92   235824862
# ..                       ...     ...                  ...         ...
# 56                   Bahrain    4.99                17.72     1472233
# 57                   Estonia   18.74                72.08     1326062
# 58                Luxembourg   21.66                66.69      647599
# 59                     Malta   15.87                70.49      533286
# 60                   Iceland   18.45                22.15      372899
#
# [61 rows x 4 columns]

# %%
df
# Out:
#                      country  talent  government_strategy  population
# 0                      China   16.51                94.87  1425887337
# 1                      India   45.27                58.83  1417173173
# 2   United States of America  100.00                77.39   338289857
# 3                  Indonesia    5.51                59.99   275501339
# 4                   Pakistan    8.00                13.92   235824862
# ..                       ...     ...                  ...         ...
# 56                   Bahrain    4.99                17.72     1472233
# 57                   Estonia   18.74                72.08     1326062
# 58                Luxembourg   21.66                66.69      647599
# 59                     Malta   15.87                70.49      533286
# 60                   Iceland   18.45                22.15      372899
#
# [61 rows x 4 columns]

# %%
countries = df['country']
populations = df['population']   # Convert population to millions
talents = df['talent']

# Create a bubble chart
plt.figure(figsize=(10, 6))
scatter = plt.scatter(populations, talents, s=populations / 1e6, alpha=0.4, c=talents, cmap='viridis', edgecolors='w', linewidth=0.5)

# Add labels and title
plt.xlabel('Population')
plt.ylabel('Talent')
plt.title('Population vs Talent by Country ')

# Add color bar to indicate talent score
plt.colorbar(scatter, label='Talent')

# Show the plot
plt.tight_layout()
plt.show()

# %%
populations = df['population'] / 1e6  # Convert population to millions
talents = df['talent']

# Create a bubble chart
plt.figure(figsize=(12, 8))
scatter = plt.scatter(populations, talents, s=df['population'] / 1e6, alpha=0.5, c=talents, cmap='viridis', edgecolors='w', linewidth=0.5)

# Add labels and title
plt.xlabel('Population (in millions)')
plt.ylabel('Talent')
plt.title('Population vs Talent by Country')

# Add color bar to indicate talent score
plt.colorbar(scatter, label='Talent')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **2.GRAPH**

# %%
df2= pd.read_csv('tables/high_gs_low_talent.csv', delimiter=',')

# %%
df2
# Out:
#                  Country  government_strategy  talent
# 0                  China                94.87   16.51
# 1            South Korea                87.50   14.54
# 2                  Japan                71.96   15.18
# 3           Saudi Arabia                91.63    4.49
# 4                Belgium                63.58   15.17
# 5                 Poland                78.14   14.21
# 6               Slovenia                80.38   13.02
# 7                  Italy                61.43   11.09
# 8                 Russia                90.40   12.46
# 9                  Malta                70.49   15.87
# 10  United Arab Emirates                81.38    2.65
# 11              Portugal                70.69   13.43
# 12        Czech Republic                70.29   11.11
# 13             Lithuania                64.28   14.30
# 14                Brazil                67.72   13.46
# 15                 Chile                60.50   10.56
# ...

# %%
# Plotting talent scores with vertical country names
plt.figure(figsize=(10, 8))

# Scatter plot
plt.scatter(df2['Country'], df2['talent'], color='blue', marker='o', s=100)

# Set x-axis labels vertically
plt.xticks(rotation=90)

# Labels and title
plt.xlabel('Country')
plt.ylabel('Talent Score')
plt.title('Talent Scores by Country')

# Display plot
plt.tight_layout()
plt.show()

# %%
# Plotting talent scores and government strategy
plt.figure(figsize=(12, 8))

# Scatter plot for talent scores
plt.scatter(df2['Country'], df2['talent'], color='blue', marker='o', s=100, label='Talent Score')

# Scatter plot for government strategy
plt.scatter(df2['Country'], df2['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Display government strategy values on the right side
for i, (talent, gov_strategy) in enumerate(zip(df2['talent'], df2['government_strategy'])):
    plt.text(i, gov_strategy, f"{gov_strategy:.2f}", va='center', ha='left', fontsize=10, color='red')

# Set x-axis labels vertically
plt.xticks(rotation=90)

# Labels and title
plt.xlabel('Country')
plt.ylabel('Score')
plt.title('Talent Scores and Government Strategy by Country')
plt.legend()

# Display plot
plt.tight_layout()
plt.show()

# %%
# Plotting talent scores and government strategy
plt.figure(figsize=(12, 8))

# Scatter plot for talent scores
plt.scatter(df2['Country'], df2['talent'], color='blue', marker='o', s=100, label='Talent Score')

# Scatter plot for government strategy
plt.scatter(df2['Country'], df2['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Display government strategy values on the right side
for i, (talent, gov_strategy) in enumerate(zip(df2['talent'], df2['government_strategy'])):
    plt.text(i, gov_strategy, f"{gov_strategy:.2f}", va='center', ha='left', fontsize=9, color='red')

# Set x-axis labels vertically
plt.xticks(rotation=90)

# Labels and title
plt.xlabel('Country')
plt.ylabel('Score')
plt.title('Talent Scores and Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent Score')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))

# Scatter plot for talent scores
ax1.scatter(df2['Country'], df2['talent'], color='blue', marker='o', s=100, label='Talent Score')

# Scatter plot for government strategy
ax2 = ax1.twinx()
ax2.scatter(df2['Country'], df2['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Set y-axis limit for ax2 to start from 0
ax2.set_ylim(0, max(df2['government_strategy']) * 1.1)  # Adjust multiplier as needed for padding

# Set x-axis labels vertically
ax1.set_xticklabels(df2['Country'], rotation=90)

# Labels and title
ax1.set_xlabel('Country')
ax1.set_ylabel('Talent Score', color='blue')
ax2.set_ylabel('Government Strategy', color='red')
plt.title('Talent Scores and Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent Score')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16712\1542700136.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df2['Country'], rotation=90)

# %%
# Plotting talent scores and government strategy
fig, ax1 = plt.subplots(figsize=(12, 8))

# Scatter plot for talent scores
ax1.scatter(df2['Country'], df2['talent'], color='blue', marker='o', s=100, label='Talent Score')

# Scatter plot for government strategy
ax2 = ax1.twinx()
ax2.scatter(df2['Country'], df2['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Set y-axis limit for ax1 (talent score) to go up to 100
ax1.set_ylim(0, 100)

# Set y-axis limit for ax2 (government strategy) to start from 0
ax2.set_ylim(0, max(df2['government_strategy']) * 1.1)  # Adjust multiplier as needed for padding

# Set x-axis labels vertically
ax1.set_xticklabels(df2['Country'], rotation=90)

# Labels and title
ax1.set_xlabel('Country')
ax1.set_ylabel('Talent Score', color='blue')
ax2.set_ylabel('Government Strategy', color='red')
plt.title('Lowest Talent Scores Values Having Highest Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent Score')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16712\965933441.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df2['Country'], rotation=90)

# %% [markdown]
# **3. GRAPH**

# %%
df3= pd.read_csv('tables/low_gs_high_talent.csv', delimiter=',')
df3
# Out:
#        Country  government_strategy  talent
# 0       Israel                43.91   35.76
# 1  Switzerland                12.18   25.63
# 2       Sweden                40.35   28.21
# 3    Hong Kong                33.29   17.56
# 4  New Zealand                47.62   23.30
# 5      Iceland                22.15   18.45

# %%
fig, ax1 = plt.subplots(figsize=(8, 6))

# Scatter plot for talent scores
ax1.scatter(df3['Country'], df3['talent'], color='blue', marker='o', s=100, label='Talent Score')

# Scatter plot for government strategy
ax2 = ax1.twinx()
ax2.scatter(df3['Country'], df3['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Set y-axis limit for ax1 (talent score) to go up to 100
ax1.set_ylim(0, 100)

# Set y-axis limit for ax2 (government strategy) to start from 0
ax2.set_ylim(0, max(df3['government_strategy']) * 1.1)  # Adjust multiplier as needed for padding

# Set x-axis labels vertically
ax1.set_xticklabels(df3['Country'], rotation=90)

# Labels and title
ax1.set_xlabel('Country')
ax1.set_ylabel('Talent Score', color='blue')
ax2.set_ylabel('Government Strategy', color='red')
plt.title('Highest Talent Scores Values Having LOWEST Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent Score')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16712\647462381.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df3['Country'], rotation=90)

# %%
df4= pd.read_csv('tables/highest_talent_score.csv', delimiter=',')

# %%
df4
# Out:
#                      country  talent
# 0   United States of America  100.00
# 1                      India   45.27
# 2             United Kingdom   39.65
# 3                  Singapore   39.38
# 4                     Israel   35.76
# ..                       ...     ...
# 56      United Arab Emirates    2.65
# 57                    Mexico    1.72
# 58                     Egypt    1.11
# 59                     Kenya    0.75
# 60                     Qatar    0.00
#
# [61 rows x 2 columns]

# %%
df4 = df4.sort_values(by='talent', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(30, 10))
plt.barh(df4['country'], df4['talent'], color='skyblue')
plt.xlabel('talent')
plt.ylabel('country')
plt.title('Talent Scores by Country')
plt.gca().invert_yaxis()  # Invert y-axis to have highest talent score at the top
plt.show()

# %%
# Plotting talent and government strategy
fig, ax1 = plt.subplots(figsize=(12, 8))

# Scatter plot for talent
ax1.scatter(df3['Country'], df3['talent'], color='blue', marker='o', s=100, label='Talent')

# Scatter plot for government strategy
ax2 = ax1.twinx()
ax2.scatter(df3['Country'], df3['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Set y-axis limit for ax1 (talent) to go up to 100
ax1.set_ylim(0, 100)

# Set y-axis limit for ax2 (government strategy) to start from 0
ax2.set_ylim(0, max(df3['government_strategy']) * 1.1)  # Adjust multiplier as needed for padding

# Set x-axis labels vertically
ax1.set_xticklabels(df3['Country'], rotation=90)

# Labels and title
ax1.set_xlabel('country')
ax1.set_ylabel('talent', color='blue')
ax2.set_ylabel('Government Strategy', color='red')
plt.title('Talent and Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16712\3788833366.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df3['Country'], rotation=90)

# %%
df3
# Out:
#        Country  government_strategy  talent
# 0       Israel                43.91   35.76
# 1  Switzerland                12.18   25.63
# 2       Sweden                40.35   28.21
# 3    Hong Kong                33.29   17.56
# 4  New Zealand                47.62   23.30
# 5      Iceland                22.15   18.45

# %%
# Plotting talent and government strategy
fig, ax1 = plt.subplots(figsize=(12, 8))

# Scatter plot for talent
ax1.scatter(df3['Country'], df3['talent'], color='blue', marker='o', s=100, label='Talent')

# Scatter plot for government strategy
ax2 = ax1.twinx()
ax2.scatter(df3['Country'], df3['government_strategy'], color='red', marker='o', s=100, label='Government Strategy')

# Set y-axis limit for ax1 (talent) to go up to 100
ax1.set_ylim(0, 100)

# Set y-axis limit for ax2 (government strategy) to go up to 100
ax2.set_ylim(0, 100)

# Set x-axis labels vertically
ax1.set_xticklabels(df3['Country'], rotation=90)

# Labels and title
ax1.set_xlabel('Country')
ax1.set_ylabel('Talent', color='blue')
ax2.set_ylabel('Government Strategy', color='red')
plt.title('Talent and Government Strategy by Country')

# Create a legend for the plot
blue_marker = plt.Line2D([], [], color='blue', marker='o', markersize=10, linestyle='None', label='Talent')
red_marker = plt.Line2D([], [], color='red', marker='o', markersize=10, linestyle='None', label='Government Strategy')
plt.legend(handles=[blue_marker, red_marker], loc='upper left')

# Display plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16712\1236275080.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df3['Country'], rotation=90)

# %%
df3
# Out:
#        Country  government_strategy  talent
# 0       Israel                43.91   35.76
# 1  Switzerland                12.18   25.63
# 2       Sweden                40.35   28.21
# 3    Hong Kong                33.29   17.56
# 4  New Zealand                47.62   23.30
# 5      Iceland                22.15   18.45
