# %%
import pandas as pd

# %%
path1 = "Data Frames/ai_data.csv"
df_ai_merg = pd.read_csv(path1)
pd.set_option('display.max_columns', None)
df_ai_merg
# Out:
#                      country  talent  infrastructure  operating_environment  \
# 0   United States of America  100.00           94.02                  64.56
# 1                      China   16.51          100.00                  91.57
# 2             United Kingdom   39.65           71.43                  74.65
# 3                     Canada   31.28           77.05                  93.94
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 56                 Sri Lanka    6.27           34.64                  35.79
# 57                     Egypt    1.11           38.84                   0.00
# 58                     Kenya    0.75           14.11                  29.84
# 59                   Nigeria    2.74            0.00                  50.10
# 60                  Pakistan    8.00            2.43                  12.48
#
# ...

# %%
path2 = "Data Frames/ai_invest.csv"
df_ai_invest = pd.read_csv(path2)
pd.set_option('display.max_columns', None)
df_ai_invest
# Out:
#         country  gdp_per_capta  government_strategy  commercial
# 0    Luxembourg         127046                66.69        4.68
# 1        Norway         106594                59.05        3.95
# 2       Ireland         105362                69.44        3.94
# 3   Switzerland          92410                12.18        7.76
# 4         Qatar          88046                33.49        0.00
# ..          ...            ...                  ...         ...
# 56    Sri Lanka           3408                35.57        0.09
# 57        India           2389                58.83        7.39
# 58      Nigeria           2184                 7.75        0.33
# 59        Kenya           2099                 7.75        0.31
# 60     Pakistan           1597                13.92        0.27
#
# [61 rows x 4 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set the positions and width for the bars
bar_width = 0.35
positions = np.arange(len(df_ai_invest))

# Plot for GDP per capita
fig, ax1 = plt.subplots(figsize=(12, 8))

ax1.bar(positions, df_ai_invest['gdp_per_capta'], width=bar_width, label='GDP per Capita')

ax1.set_xlabel('Country')
ax1.set_ylabel('GDP per Capita')
ax1.set_title('GDP per Capita by Country')
ax1.set_xticks(positions)
ax1.set_xticklabels(df_ai_invest['country'], rotation=90)
ax1.legend()

# %%
# Plot for Government Strategy and Commercial
fig, ax2 = plt.subplots(figsize=(12, 8))

bar_width = 0.35
ax2.bar(positions - bar_width/2, df_ai_invest['government_strategy'], width=bar_width, label='Government Strategy')
ax2.bar(positions + bar_width/2, df_ai_invest['commercial'], width=bar_width, label='Commercial')

ax2.set_xlabel('Country')
ax2.set_ylabel('Values')
ax2.set_title('Government Strategy and Commercial by Country')
ax2.set_xticks(positions)
ax2.set_xticklabels(df_ai_invest['country'], rotation=90)
ax2.legend()

# Show the plots
plt.show()

# %%
df_ai_merg.head(10)
# Out:
#                     country  talent  infrastructure  operating_environment  \
# 0  United States of America  100.00           94.02                  64.56
# 1                     China   16.51          100.00                  91.57
# 2            United Kingdom   39.65           71.43                  74.65
# 3                    Canada   31.28           77.05                  93.94
# 4                    Israel   35.76           67.58                  82.44
# 5                 Singapore   39.38           84.30                  43.15
# 6               South Korea   14.54           85.23                  68.86
# 7           The Netherlands   33.83           81.99                  88.05
# 8                   Germany   27.63           77.22                  70.22
# 9                    France   28.32           77.15                  80.02
#
#    research  development  government_strategy  commercial  total_score  \
# ...
